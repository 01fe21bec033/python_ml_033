# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('/content/drive/MyDrive/cricket players.csv')
print(data)
data.plot()
# Out:
#        Name  Runs  Batting Avg  Strike rate
# 0      Ryan   100         45.8          100
# 1  Malatesh   200         38.7          200
# 2     Rahul   300         65.8          128
# 3    Pranav   120         55.4          136
# 4    Nitish   250         77.5          145
# <Axes: >

# %% [markdown]
# 1. Read a CSV file with data in multiple columns and compute mean, median mode of each of the columns.

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/cricket players.csv')
data.mean()
# Out:
# <ipython-input-3-d85a75e1577c>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# Runs           194.00
# Batting Avg     56.64
# Strike rate    141.80
# dtype: float64

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/cricket players.csv')
data.median()
# Out:
# <ipython-input-4-bb982e22e7f4>:3: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# Runs           200.0
# Batting Avg     55.4
# Strike rate    136.0
# dtype: float64

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/cricket players.csv')
data.mode()
# Out:
#        Name  Runs  Batting Avg  Strike rate
# 0  Malatesh   100         38.7          100
# 1    Nitish   120         45.8          128
# 2    Pranav   200         55.4          136
# 3     Rahul   250         65.8          145
# 4      Ryan   300         77.5          200

# %%
import random
import csv
from google.colab import files
import pandas as pd

computer_wins = 0
user_wins = 0
game_data = []

while True:
    computer = random.randint(1, 9)
    user_input = int(input("Enter a number between 1 and 9: "))
    print("Computer's number:", computer)
    print("Your guess:", user_input)

    round_result = ""

    if computer > user_input:
        round_result = "Computer won"
        computer_wins += 1
    elif computer == user_input:
        round_result = "Tie"
    else:
        round_result = "You won"
        user_wins += 1

    game_data.append({'User Guess': user_input, 'Computer Number': computer, 'Result': round_result})

    print("User wins:", user_wins, "Computer wins:", computer_wins)

    play_again = input("Do you want to play again? (y/n): ")
    if play_again.lower() != 'y':
        break

# Create a DataFrame from game data
df = pd.DataFrame(game_data)

# Export DataFrame to an Excel file
excel_filename = 'game_results.xlsx'
df.to_excel(excel_filename, index=False)
files.download(excel_filename)
# Out:
# Enter a number between 1 and 9: 6
# Computer's number: 2
# Your guess: 6
# User wins: 1 Computer wins: 0
# Do you want to play again? (y/n): y
# Enter a number between 1 and 9: 4
# Computer's number: 1
# Your guess: 4
# User wins: 2 Computer wins: 0
# Do you want to play again? (y/n): y
# Enter a number between 1 and 9: 7
# Computer's number: 6
# Your guess: 7
# User wins: 3 Computer wins: 0
# Do you want to play again? (y/n): y
# Enter a number between 1 and 9: 1
# Computer's number: 8
# Your guess: 1
# User wins: 3 Computer wins: 1
# Do you want to play again? (y/n): y
# Enter a number between 1 and 9: 3
# Computer's number: 1
# Your guess: 3
# User wins: 4 Computer wins: 1
# Do you want to play again? (y/n): n
